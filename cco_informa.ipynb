# %% [markdown]
# <a href="https://colab.research.google.com/github/NGS-Adryan/sheet_cco/blob/main/cco_informa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gspread
from google.colab import auth
from google.auth import default
from google.auth.transport.requests import Request

import pandas as pd

# %%
auth.authenticate_user()
credentials, _ = default()
gc = gspread.authorize(credentials)

# %%
ws = gc.open('Monitoramento')
ss = ws.get_worksheet(0)
dados = ss.get_all_records()

# %%
df = pd.DataFrame(dados)

# %%
quebras = df[(df['Problema'] != '')&(df['Problema'] != 'Problemas na viagem anterior')]

quebras = quebras[['Data', 'Carro', 'Problema']]
quebras.head(5)

cars = []

for car in quebras['Carro']:
  for problem in quebras['Problema']:
    print(car) if car
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6457
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# 6694
# ...

# %%
df = pd.DataFrame(dados)
df

# %%
dados_adryan = df[(df['Operador'] == 'Adryan')&(df['Carro Substituto'] != '')]

# %%
dados_adryan.head(10)
# Out:
#           Data    Tabela Linha Carro Carro Substituto   Hora Sentido  \
# 31  01/11/2023   B55/016   B55  6484             6417  19:29      BB
# 51  03/11/2023   652/006   654  6434             6433  11:53       2
# 54  03/11/2023   656/012   756  6580             6586  15:28       1
# 63  03/11/2023  6372/009  6372  6101             6140  16:45       2
# 64  03/11/2023   727/009   721  6699             6717  17:35       1
# 70  04/11/2023   718/004   718  6115             6141  15:10       1
# 71  04/11/2023   627/014   621  6694             6772  16:08       1
# 73  04/11/2023   632/004   632  6736             6604  16:25       1
# 74  04/11/2023  6372/004  6372  6142             6151  16:25       1
# 98  06/11/2023   B51/018   631  6670             6802  12:55      BB
#
#                                          Ocorrência  \
# 31        Problemas mecânicos - Viagem interrompida
# 51        Problemas mecânicos - Viagem interrompida
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('Problema').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
